# %%
from sklearn import linear_model
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from numpy import sqrt
plt.rcParams["figure.figsize"] = [10,8]

# %%
boston = load_boston()
x, y = boston.data, boston.target
xtrain, xtest, ytrain, ytest=train_test_split(x, y, test_size=0.15)

# %%
lars = linear_model.Lars().fit(xtrain, ytrain)

# %%
lars
# Out:
# Lars(copy_X=True, eps=2.220446049250313e-16, fit_intercept=True, fit_path=True,
#      n_nonzero_coefs=500, normalize=True, precompute='auto', verbose=False)

# %%
lars.coef_
# Out:
# array([-1.40580636e-01,  8.14511605e-03, -2.73065638e-01,  2.74017686e+00,
#        -2.18937593e+01,  4.31051386e+00, -1.02570910e-03, -1.63362269e+00,
#        -1.51680395e-01,  2.30853487e-02, -1.11448832e+00,  1.07490466e-02,
#        -5.20720298e-01])

# %%
ypred = lars.predict(xtest)

# %%
mse = mean_squared_error(ytest,ypred)

# %%
rmse = sqrt(mse)

# %%
x_ax = range(len(ytest))
plt.scatter(x_ax, ytest, s=5, color="blue", label="original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()

# %%
lassolars = linear_model.LassoLars(alpha =.1).fit(xtrain, ytrain)

# %%
lassolars.coef_
# Out:
# array([ 0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#         3.22238939,  0.        ,  0.        ,  0.        ,  0.        ,
#        -0.30280758,  0.        , -0.43343296])

# %%
ypred = lassolars.predict(xtest)
mse = mean_squared_error(ytest,ypred)
print(mse)
rmse = sqrt(mse)
print(rmse)
# Out:
# 48.83179568210353
# 6.987975077381396

# %%
x_ax = range(len(ytest))
plt.scatter(x_ax,ytest, s=5, color="blue", label = "original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()
